# %% [markdown]
# A PyGal documentation by Mukul Pathak. http://mukulpathak.com

# %% [markdown]
# ### PyGal Reference Guide
# Source:
#     http://www.pygal.org/en/stable/documentation/index.html

# %% [markdown]
# PyGal is a python SVG (Scalable Vector Graphics) Charts Creator. It defines in vector based graphics in XML format. In this document we will use PyGal and see it's various features.

# %% [markdown]
# To install PyGal in our systems, we will run the "pip install pygal" command on terminal or with an "!" on jupyter notebook as shown below.

# %%
# !pip install pygal
# Out:
# Requirement already satisfied: pygal in /Users/mukulpathak/opt/miniconda3/lib/python3.7/site-packages (2.4.0)

# %%
#We then import pygal and other important packages
import pygal
import pandas as pd
import numpy as np

# %% [markdown]
# ##### First we will run a basic program involving PyGal.
# ## 1. Use of Line Chart
# Here, I have collected data from PyGal's documentation website showing browser usage in percentage.

# %%
line_chart = pygal.Line()        #Calls Line functionality of PyGal
line_chart.title = 'Browser usage evolution (in %)'
line_chart.x_labels = map(str, range(2002, 2013))
line_chart.add('Firefox', [None, None,    0, 16.6,   25,   31, 36.4, 45.5, 46.3, 42.8, 37.1])
line_chart.add('Chrome',  [None, None, None, None, None,    0,  3.9, 10.8, 23.8, 35.3])
line_chart.add('IE',      [85.8, 84.6, 84.7, 74.5,   66, 58.6, 54.7, 44.8, 36.2, 26.6, 20.1])
line_chart.add('Others',  [14.2, 15.4, 15.3,  8.9,    9, 10.4,  8.9,  5.8,  6.7,  6.8,  7.5])
line_chart.render_to_file('pic.svg')

# %% [markdown]
# This will create an svg file named "pic.svg" in the current directory.

# %% [markdown]
# In order to render the visualisations on IPYNB file, we will run the following HTML code which will fetch scripts from Github repos involving jquery.js & tooltips.min.js. And then render the charts on browser.

# %%
from IPython.display import display, HTML

base_html = """
<!DOCTYPE html>
<html>
  <head>
  <script type="text/javascript" src="http://kozea.github.com/pygal.js/javascripts/svg.jquery.js"></script>
  <script type="text/javascript" src="https://kozea.github.io/pygal.js/2.0.x/pygal-tooltips.min.js""></script>
  </head>
  <body>
    <figure>
      {rendered_chart}
    </figure>
  </body>
</html>
"""

# %% [markdown]
# Now, we will perform visualisation on 2013 movie database fetched from tmdb. This db has a total of 71 movie entries from 2017 and has 13 columns depicting different details of the movie. We will see those in detail while running the .head() command

# %%
tmdb = pd.read_csv("tmdb.csv")  # Load the dataset
tmdb.head()
# Out:
#       budget                                             genres      id  \
# 0   15000000  [{"id": 53, "name": "Thriller"}, {"id": 878, "...  333371
# 1   50000000  [{"id": 28, "name": "Action"}, {"id": 18, "nam...  300671
# 2    4500000  [{"id": 53, "name": "Thriller"}, {"id": 28, "n...  375290
# 3  170000000                    [{"id": 14, "name": "Fantasy"}]  241259
# 4  110000000  [{"id": 12, "name": "Adventure"}, {"id": 878, ...  262504
#
#                                             keywords  popularity  \
# 0  [{"id": 1930, "name": "kidnapping"}, {"id": 23...   53.698683
# 1  [{"id": 818, "name": "based on novel"}, {"id":...   42.526529
# 2  [{"id": 2227, "name": "evacuation"}, {"id": 60...    2.551559
# 3  [{"id": 818, "name": "based on novel"}, {"id":...   56.268916
# 4  [{"id": 818, "name": "based on novel"}, {"id":...   86.105615
#
#                                 production_companies production_countries  \
# 0  [{"name": "Paramount Pictures", "id": 4}, {"na...                   us
# 1  [{"name": "Paramount Pictures", "id": 4}, {"na...                   mt
# 2  [{"name": "T-Series", "id": 3522}, {"name": "H...                   in
# 3  [{"name": "Walt Disney Pictures", "id": 2}, {"...                   gb
# 4  [{"name": "Summit Entertainment", "id": 491}, ...                   us
#
#   release_date    revenue  runtime                                      title  \
# 0      3/10/16  108286421      103                        10 Cloverfield Lane
# 1      1/13/16   69411370      144  13 Hours: The Secret Soldiers of Benghazi
# 2      1/22/16   32000000      126                                    Airlift
# 3      5/25/16  299370084      113            Alice Through the Looking Glass
# 4       3/9/16  179246868      121                                  Allegiant
#
#    vote_average  vote_count
# 0           6.8        2468
# 1           7.0         938
# 2           7.3          57
# 3           6.5        1725
# 4           5.9        1998

# %% [markdown]
# ##### Using PyGal bar graph, we will first find top 10 movies with highest budget.
# ## 2. Use of Bar Chart

# %%
Mobudget=tmdb.groupby('title')['budget'].mean()
Mobudget.head(10)
# Out:
# title
# 10 Cloverfield Lane                           15000000
# 13 Hours: The Secret Soldiers of Benghazi     50000000
# Airlift                                        4500000
# Alice Through the Looking Glass              170000000
# Allegiant                                    110000000
# Bad Moms                                      20000000
# Batman v Superman: Dawn of Justice           250000000
# Ben-Hur                                      100000000
# Captain America: Civil War                   250000000
# Central Intelligence                          50000000
# Name: budget, dtype: int64

# %%
bar_chart = pygal.Bar(height=400)
[bar_chart.add(x[0], x[1]) for x in Mobudget.items()]
display(HTML(base_html.format(rendered_chart=bar_chart.render(is_unicode=True))))  #This line will render the graphs on our IPYNB file itself
# Out:
# <!DOCTYPE html>
# <html>
#   <head>
#   <script type="text/javascript" src="http://kozea.github.com/pygal.js/javascripts/svg.jquery.js"></script>
#   <script type="text/javascript" src="https://kozea.github.io/pygal.js/2.0.x/pygal-tooltips.min.js""></script>
#   </head>
#   <body>
#     <figure>
#       <?xml version='1.0' encoding='utf-8'?>
# <svg xmlns:xlink="http://www.w3.org/1999/xlink" class="pygal-chart" id="chart-49e41641-dec2-4b19-84d2-130b8bb40dd7" viewBox="0 0 800 400" xmlns="http://www.w3.org/2000/svg"><!--Generated with pygal 2.4.0 (etree) ©Kozea 2012-2016 on 2020-04-07--><!--http://pygal.org--><!--http://github.com/Kozea/pygal--><defs><style type="text/css">#chart-49e41641-dec2-4b19-84d2-130b8bb40dd7{-webkit-user-select:none;-webkit-font-smoothing:antialiased;font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace}#chart-49e41641-dec2-4b19-84d2-130b8bb40dd7 .title{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:16px}#chart-49e41641-dec2-4b19-84d2-130b8bb40dd7 .legends .legend text{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:14px}#chart-49e41641-dec2-4b19-84d2-130b8bb40dd7 .axis text{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-49e41641-dec2-4b19-84d2-130b8bb40dd7 .axis text.major{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-49e41641-dec2-4b19-84d2-130b8bb40dd7 .text-overlay text.value{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:16px}#chart-49e41641-dec2-4b19-84d2-130b8bb40dd7 .text-overlay text.label{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-49e41641-dec2-4b19-84d2-130b8bb40dd7 .tooltip{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:14px}#chart-49e41641-dec2-4b19-84d2-130b8bb40dd7 text.no_data{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:64px}
# #chart-49e41641-dec2-4b19-84d2-130b8bb40dd7{background-color:rgba(249,249,249,1)}#chart-49e41641-dec2-4b19-84d2-130b8bb40dd7 path,#chart-49e41641-dec2-4b19-84d2-130b8bb40dd7 line,#chart-49e41641-dec2-4b19-84d2-130b8bb40dd7 rect,#chart-49e41641-dec2-4b19-84d2-130b8bb40dd7 circle{-webkit-transition:150ms;-moz-transition:150ms;transition:150ms}#chart-49e41641-dec2-4b19-84d2-130b8bb40dd7 .graph &gt; .background{fill:rgba(249,249,249,1)}#chart-49e41641-dec2-4b19-84d2-130b8bb40dd7 .plot &gt; .background{fill:rgba(255,255,255,1)}#chart-49e41641-dec2-4b19-84d2-130b8bb40dd7 .graph{fill:rgba(0,0,0,.87)}#chart-49e41641-dec2-4b19-84d2-130b8bb40dd7 text.no_data{fill:rgba(0,0,0,1)}#chart-49e41641-dec2-4b19-84d2-130b8bb40dd7 .title{fill:rgba(0,0,0,1)}#chart-49e41641-dec2-4b19-84d2-130b8bb40dd7 .legends .legend text{fill:rgba(0,0,0,.87)}#chart-49e41641-dec2-4b19-84d2-130b8bb40dd7 .legends .legend:hover text{fill:rgba(0,0,0,1)}#chart-49e41641-dec2-4b19-84d2-130b8bb40dd7 .axis .line{stroke:rgba(0,0,0,1)}#chart-49e41641-dec2-4b19-84d2-130b8bb40dd7 .axis .guide.line{stroke:rgba(0,0,0,.54)}#chart-49e41641-dec2-4b19-84d2-130b8bb40dd7 .axis .major.line{stroke:rgba(0,0,0,.87)}#chart-49e41641-dec2-4b19-84d2-130b8bb40dd7 .axis text.major{fill:rgba(0,0,0,1)}#chart-49e41641-dec2-4b19-84d2-130b8bb40dd7 .axis.y .guides:hover .guide.line,#chart-49e41641-dec2-4b19-84d2-130b8bb40dd7 .line-graph .axis.x .guides:hover .guide.line,#chart-49e41641-dec2-4b19-84d2-130b8bb40dd7 .stackedline-graph .axis.x .guides:hover .guide.line,#chart-49e41641-dec2-4b19-84d2-130b8bb40dd7 .xy-graph .axis.x .guides:hover .guide.line{stroke:rgba(0,0,0,1)}#chart-49e41641-dec2-4b19-84d2-130b8bb40dd7 .axis .guides:hover text{fill:rgba(0,0,0,1)}#chart-49e41641-dec2-4b19-84d2-130b8bb40dd7 .reactive{fill-opacity:.7;stroke-opacity:.8}#chart-49e41641-dec2-4b19-84d2-130b8bb40dd7 .ci{stroke:rgba(0,0,0,.87)}#chart-49e41641-dec2-4b19-84d2-130b8bb40dd7 .reactive.active,#chart-49e41641-dec2-4b19-84d2-130b8bb40dd7 .active .reactive{fill-opacity:.8;stroke-opacity:.9;stroke-width:4}#chart-49e41641-dec2-4b19-84d2-130b8bb40dd7 .ci .reactive.active{stroke-width:1.5}#chart-49e41641-dec2-4b19-84d2-130b8bb40dd7 .series text{fill:rgba(0,0,0,1)}#chart-49e41641-dec2-4b19-84d2-130b8bb40dd7 .tooltip rect{fill:rgba(255,255,255,1);stroke:rgba(0,0,0,1);-webkit-transition:opacity 150ms;-moz-transition:opacity 150ms;transition:opacity 150ms}#chart-49e41641-dec2-4b19-84d2-130b8bb40dd7 .tooltip .label{fill:rgba(0,0,0,.87)}#chart-49e41641-dec2-4b19-84d2-130b8bb40dd7 .tooltip .label{fill:rgba(0,0,0,.87)}#chart-49e41641-dec2-4b19-84d2-130b8bb40dd7 .tooltip .legend{font-size:.8em;fill:rgba(0,0,0,.54)}#chart-49e41641-dec2-4b19-84d2-130b8bb40dd7 .tooltip .x_label{font-size:.6em;fill:rgba(0,0,0,1)}#chart-49e41641-dec2-4b19-84d2-130b8bb40dd7 .tooltip .xlink{font-size:.5em;text-decoration:underline}#chart-49e41641-dec2-4b19-84d2-130b8bb40dd7 .tooltip .value{font-size:1.5em}#chart-49e41641-dec2-4b19-84d2-130b8bb40dd7 .bound{font-size:.5em}#chart-49e41641-dec2-4b19-84d2-130b8bb40dd7 .max-value{font-size:.75em;fill:rgba(0,0,0,.54)}#chart-49e41641-dec2-4b19-84d2-130b8bb40dd7 .map-element{fill:rgba(255,255,255,1);stroke:rgba(0,0,0,.54) !important}#chart-49e41641-dec2-4b19-84d2-130b8bb40dd7 .map-element .reactive{fill-opacity:inherit;stroke-opacity:inherit}#chart-49e41641-dec2-4b19-84d2-130b8bb40dd7 .color-0,#chart-49e41641-dec2-4b19-84d2-130b8bb40dd7 .color-0 a:visited{stroke:#f44336;fill:#f44336}#chart-49e41641-dec2-4b19-84d2-130b8bb40dd7 .color-1,#chart-49e41641-dec2-4b19-84d2-130b8bb40dd7 .color-1 a:visited{stroke:#3f51b5;fill:#3f51b5}#chart-49e41641-dec2-4b19-84d2-130b8bb40dd7 .color-2,#chart-49e41641-dec2-4b19-84d2-130b8bb40dd7 .color-2 a:visited{stroke:#009688;fill:#009688}#chart-49e41641-dec2-4b19-84d2-130b8bb40dd7 .color-3,#chart-49e41641-dec2-4b19-84d2-130b8bb40dd7 .color-3 a:visited{stroke:#ffc107;fill:#ffc107}#chart-49e41641-dec2-4b19-84d2-130b8bb40dd7 .color-4,#chart-49e41641-dec2-4b19-84d2-130b8bb40dd7 .color-4 a:visit ...

# %% [markdown]
# ##### We will create a popularity chart depicting popularity of the movie.
# ## 3. Use of Treemap/Area chart

# %%
popularityChart = tmdb.groupby(['title'])['popularity'].apply(list) #convert all the movies into a lit form by grouping popularity & title
popularityChart
# Out:
# title
# 10 Cloverfield Lane                          [53.698682999999996]
# 13 Hours: The Secret Soldiers of Benghazi             [42.526529]
# Airlift                                                [2.551559]
# Alice Through the Looking Glass              [56.268916000000004]
# Allegiant                                             [86.105615]
#                                                      ...
# The Young Messiah                            [1.8845580000000002]
# Triple 9                                              [29.371987]
# Warcraft                                              [63.148529]
# X-Men: Apocalypse                                    [139.272042]
# Zoolander 2                                           [37.253774]
# Name: popularity, Length: 71, dtype: object

# %%
treemap = pygal.Treemap(height=300)    #calling the treemap functionality
[treemap.add(x[0], x[1]) for x in popularityChart.items()] #fetching all the inputs from the dataframe
display(HTML(base_html.format(rendered_chart=treemap.render(is_unicode=True)))) #Running the same on ipynb
# Out:
# <!DOCTYPE html>
# <html>
#   <head>
#   <script type="text/javascript" src="http://kozea.github.com/pygal.js/javascripts/svg.jquery.js"></script>
#   <script type="text/javascript" src="https://kozea.github.io/pygal.js/2.0.x/pygal-tooltips.min.js""></script>
#   </head>
#   <body>
#     <figure>
#       <?xml version='1.0' encoding='utf-8'?>
# <svg xmlns:xlink="http://www.w3.org/1999/xlink" class="pygal-chart" id="chart-147980d7-1fef-468d-ba5b-e635ddcb04ea" viewBox="0 0 800 300" xmlns="http://www.w3.org/2000/svg"><!--Generated with pygal 2.4.0 (etree) ©Kozea 2012-2016 on 2020-04-07--><!--http://pygal.org--><!--http://github.com/Kozea/pygal--><defs><style type="text/css">#chart-147980d7-1fef-468d-ba5b-e635ddcb04ea{-webkit-user-select:none;-webkit-font-smoothing:antialiased;font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace}#chart-147980d7-1fef-468d-ba5b-e635ddcb04ea .title{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:16px}#chart-147980d7-1fef-468d-ba5b-e635ddcb04ea .legends .legend text{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:14px}#chart-147980d7-1fef-468d-ba5b-e635ddcb04ea .axis text{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-147980d7-1fef-468d-ba5b-e635ddcb04ea .axis text.major{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-147980d7-1fef-468d-ba5b-e635ddcb04ea .text-overlay text.value{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:16px}#chart-147980d7-1fef-468d-ba5b-e635ddcb04ea .text-overlay text.label{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-147980d7-1fef-468d-ba5b-e635ddcb04ea .tooltip{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:14px}#chart-147980d7-1fef-468d-ba5b-e635ddcb04ea text.no_data{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:64px}
# #chart-147980d7-1fef-468d-ba5b-e635ddcb04ea{background-color:rgba(249,249,249,1)}#chart-147980d7-1fef-468d-ba5b-e635ddcb04ea path,#chart-147980d7-1fef-468d-ba5b-e635ddcb04ea line,#chart-147980d7-1fef-468d-ba5b-e635ddcb04ea rect,#chart-147980d7-1fef-468d-ba5b-e635ddcb04ea circle{-webkit-transition:150ms;-moz-transition:150ms;transition:150ms}#chart-147980d7-1fef-468d-ba5b-e635ddcb04ea .graph &gt; .background{fill:rgba(249,249,249,1)}#chart-147980d7-1fef-468d-ba5b-e635ddcb04ea .plot &gt; .background{fill:rgba(255,255,255,1)}#chart-147980d7-1fef-468d-ba5b-e635ddcb04ea .graph{fill:rgba(0,0,0,.87)}#chart-147980d7-1fef-468d-ba5b-e635ddcb04ea text.no_data{fill:rgba(0,0,0,1)}#chart-147980d7-1fef-468d-ba5b-e635ddcb04ea .title{fill:rgba(0,0,0,1)}#chart-147980d7-1fef-468d-ba5b-e635ddcb04ea .legends .legend text{fill:rgba(0,0,0,.87)}#chart-147980d7-1fef-468d-ba5b-e635ddcb04ea .legends .legend:hover text{fill:rgba(0,0,0,1)}#chart-147980d7-1fef-468d-ba5b-e635ddcb04ea .axis .line{stroke:rgba(0,0,0,1)}#chart-147980d7-1fef-468d-ba5b-e635ddcb04ea .axis .guide.line{stroke:rgba(0,0,0,.54)}#chart-147980d7-1fef-468d-ba5b-e635ddcb04ea .axis .major.line{stroke:rgba(0,0,0,.87)}#chart-147980d7-1fef-468d-ba5b-e635ddcb04ea .axis text.major{fill:rgba(0,0,0,1)}#chart-147980d7-1fef-468d-ba5b-e635ddcb04ea .axis.y .guides:hover .guide.line,#chart-147980d7-1fef-468d-ba5b-e635ddcb04ea .line-graph .axis.x .guides:hover .guide.line,#chart-147980d7-1fef-468d-ba5b-e635ddcb04ea .stackedline-graph .axis.x .guides:hover .guide.line,#chart-147980d7-1fef-468d-ba5b-e635ddcb04ea .xy-graph .axis.x .guides:hover .guide.line{stroke:rgba(0,0,0,1)}#chart-147980d7-1fef-468d-ba5b-e635ddcb04ea .axis .guides:hover text{fill:rgba(0,0,0,1)}#chart-147980d7-1fef-468d-ba5b-e635ddcb04ea .reactive{fill-opacity:.7;stroke-opacity:.8}#chart-147980d7-1fef-468d-ba5b-e635ddcb04ea .ci{stroke:rgba(0,0,0,.87)}#chart-147980d7-1fef-468d-ba5b-e635ddcb04ea .reactive.active,#chart-147980d7-1fef-468d-ba5b-e635ddcb04ea .active .reactive{fill-opacity:.8;stroke-opacity:.9;stroke-width:4}#chart-147980d7-1fef-468d-ba5b-e635ddcb04ea .ci .reactive.active{stroke-width:1.5}#chart-147980d7-1fef-468d-ba5b-e635ddcb04ea .series text{fill:rgba(0,0,0,1)}#chart-147980d7-1fef-468d-ba5b-e635ddcb04ea .tooltip rect{fill:rgba(255,255,255,1);stroke:rgba(0,0,0,1);-webkit-transition:opacity 150ms;-moz-transition:opacity 150ms;transition:opacity 150ms}#chart-147980d7-1fef-468d-ba5b-e635ddcb04ea .tooltip .label{fill:rgba(0,0,0,.87)}#chart-147980d7-1fef-468d-ba5b-e635ddcb04ea .tooltip .label{fill:rgba(0,0,0,.87)}#chart-147980d7-1fef-468d-ba5b-e635ddcb04ea .tooltip .legend{font-size:.8em;fill:rgba(0,0,0,.54)}#chart-147980d7-1fef-468d-ba5b-e635ddcb04ea .tooltip .x_label{font-size:.6em;fill:rgba(0,0,0,1)}#chart-147980d7-1fef-468d-ba5b-e635ddcb04ea .tooltip .xlink{font-size:.5em;text-decoration:underline}#chart-147980d7-1fef-468d-ba5b-e635ddcb04ea .tooltip .value{font-size:1.5em}#chart-147980d7-1fef-468d-ba5b-e635ddcb04ea .bound{font-size:.5em}#chart-147980d7-1fef-468d-ba5b-e635ddcb04ea .max-value{font-size:.75em;fill:rgba(0,0,0,.54)}#chart-147980d7-1fef-468d-ba5b-e635ddcb04ea .map-element{fill:rgba(255,255,255,1);stroke:rgba(0,0,0,.54) !important}#chart-147980d7-1fef-468d-ba5b-e635ddcb04ea .map-element .reactive{fill-opacity:inherit;stroke-opacity:inherit}#chart-147980d7-1fef-468d-ba5b-e635ddcb04ea .color-0,#chart-147980d7-1fef-468d-ba5b-e635ddcb04ea .color-0 a:visited{stroke:#f44336;fill:#f44336}#chart-147980d7-1fef-468d-ba5b-e635ddcb04ea .color-1,#chart-147980d7-1fef-468d-ba5b-e635ddcb04ea .color-1 a:visited{stroke:#3f51b5;fill:#3f51b5}#chart-147980d7-1fef-468d-ba5b-e635ddcb04ea .color-2,#chart-147980d7-1fef-468d-ba5b-e635ddcb04ea .color-2 a:visited{stroke:#009688;fill:#009688}#chart-147980d7-1fef-468d-ba5b-e635ddcb04ea .color-3,#chart-147980d7-1fef-468d-ba5b-e635ddcb04ea .color-3 a:visited{stroke:#ffc107;fill:#ffc107}#chart-147980d7-1fef-468d-ba5b-e635ddcb04ea .color-4,#chart-147980d7-1fef-468d-ba5b-e635ddcb04ea .color-4 a:visit ...

# %% [markdown]
# ##### We will now see performances of each movies on gauge charts
# ## 4. Use of Gauge Chart

# %%
ratings=tmdb.groupby('title')['vote_average'].mean()  #grouping title with vote average

# %%
gauge = pygal.SolidGauge(inner_radius=0.70) #creating a gauge with radius 0.7
[gauge.add(x[0], [{"value" : x[1] * 10}] ) for x in ratings.iteritems()] #fetching values from df and getting scores out of 100.
display(HTML(base_html.format(rendered_chart=gauge.render(is_unicode=True)))) #running the command
# Out:
# <!DOCTYPE html>
# <html>
#   <head>
#   <script type="text/javascript" src="http://kozea.github.com/pygal.js/javascripts/svg.jquery.js"></script>
#   <script type="text/javascript" src="https://kozea.github.io/pygal.js/2.0.x/pygal-tooltips.min.js""></script>
#   </head>
#   <body>
#     <figure>
#       <?xml version='1.0' encoding='utf-8'?>
# <svg xmlns:xlink="http://www.w3.org/1999/xlink" class="pygal-chart" id="chart-b54144b0-166b-4448-8b37-eff6c603f931" viewBox="0 0 800 600" xmlns="http://www.w3.org/2000/svg"><!--Generated with pygal 2.4.0 (etree) ©Kozea 2012-2016 on 2020-04-07--><!--http://pygal.org--><!--http://github.com/Kozea/pygal--><defs><path d="M34.000000 8.151111 A22.960000 22.960000 0 1 1 33.999770 8.151111" id="valuePath-34.031.11111111111111" /><path d="M102.000000 8.151111 A22.960000 22.960000 0 1 1 101.999770 8.151111" id="valuePath-102.031.11111111111111" /><path d="M170.000000 8.151111 A22.960000 22.960000 0 1 1 169.999770 8.151111" id="valuePath-170.031.11111111111111" /><path d="M238.000000 8.151111 A22.960000 22.960000 0 1 1 237.999770 8.151111" id="valuePath-238.031.11111111111111" /><path d="M306.000000 8.151111 A22.960000 22.960000 0 1 1 305.999770 8.151111" id="valuePath-306.031.11111111111111" /><path d="M374.000000 8.151111 A22.960000 22.960000 0 1 1 373.999770 8.151111" id="valuePath-374.031.11111111111111" /><path d="M442.000000 8.151111 A22.960000 22.960000 0 1 1 441.999770 8.151111" id="valuePath-442.031.11111111111111" /><path

# Out:
# <!DOCTYPE html>
# <html>
#   <head>
#   <script type="text/javascript" src="http://kozea.github.com/pygal.js/javascripts/svg.jquery.js"></script>
#   <script type="text/javascript" src="https://kozea.github.io/pygal.js/2.0.x/pygal-tooltips.min.js""></script>
#   </head>
#   <body>
#     <figure>
#       <?xml version='1.0' encoding='utf-8'?>
# <svg xmlns:xlink="http://www.w3.org/1999/xlink" class="pygal-chart" id="chart-e4140fab-bc74-4c2d-b35d-0401acd50367" viewBox="0 0 800 600" xmlns="http://www.w3.org/2000/svg"><!--Generated with pygal 2.4.0 (etree) ©Kozea 2012-2016 on 2020-04-07--><!--http://pygal.org--><!--http://github.com/Kozea/pygal--><defs><style type="text/css">#chart-e4140fab-bc74-4c2d-b35d-0401acd50367{-webkit-user-select:none;-webkit-font-smoothing:antialiased;font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace}#chart-e4140fab-bc74-4c2d-b35d-0401acd50367 .title{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:16px}#chart-e4140fab-bc74-4c2d-b35d-0401acd50367 .legends .legend text{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:14px}#chart-e4140fab-bc74-4c2d-b35d-0401acd50367 .axis text{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-e4140fab-bc74-4c2d-b35d-0401acd50367 .axis text.major{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-e4140fab-bc74-4c2d-b35d-0401acd50367 .text-overlay text.value{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:16px}#chart-e4140fab-bc74-4c2d-b35d-0401acd50367 .text-overlay text.label{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-e4140fab-bc74-4c2d-b35d-0401acd50367 .tooltip{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:14px}#chart-e4140fab-bc74-4c2d-b35d-0401acd50367 text.no_data{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:64px}
# #chart-e4140fab-bc74-4c2d-b35d-0401acd50367{background-color:rgba(249,249,249,1)}#chart-e4140fab-bc74-4c2d-b35d-0401acd50367 path,#chart-e4140fab-bc74-4c2d-b35d-0401acd50367 line,#chart-e4140fab-bc74-4c2d-b35d-0401acd50367 rect,#chart-e4140fab-bc74-4c2d-b35d-0401acd50367 circle{-webkit-transition:150ms;-moz-transition:150ms;transition:150ms}#chart-e4140fab-bc74-4c2d-b35d-0401acd50367 .graph &gt; .background{fill:rgba(249,249,249,1)}#chart-e4140fab-bc74-4c2d-b35d-0401acd50367 .plot &gt; .background{fill:rgba(255,255,255,1)}#chart-e4140fab-bc74-4c2d-b35d-0401acd50367 .graph{fill:rgba(0,0,0,.87)}#chart-e4140fab-bc74-4c2d-b35d-0401acd50367 text.no_data{fill:rgba(0,0,0,1)}#chart-e4140fab-bc74-4c2d-b35d-0401acd50367 .title{fill:rgba(0,0,0,1)}#chart-e4140fab-bc74-4c2d-b35d-0401acd50367 .legends .legend text{fill:rgba(0,0,0,.87)}#chart-e4140fab-bc74-4c2d-b35d-0401acd50367 .legends .legend:hover text{fill:rgba(0,0,0,1)}#chart-e4140fab-bc74-4c2d-b35d-0401acd50367 .axis .line{stroke:rgba(0,0,0,1)}#chart-e4140fab-bc74-4c2d-b35d-0401acd50367 .axis .guide.line{stroke:rgba(0,0,0,.54)}#chart-e4140fab-bc74-4c2d-b35d-0401acd50367 .axis .major.line{stroke:rgba(0,0,0,.87)}#chart-e4140fab-bc74-4c2d-b35d-0401acd50367 .axis text.major{fill:rgba(0,0,0,1)}#chart-e4140fab-bc74-4c2d-b35d-0401acd50367 .axis.y .guides:hover .guide.line,#chart-e4140fab-bc74-4c2d-b35d-0401acd50367 .line-graph .axis.x .guides:hover .guide.line,#chart-e4140fab-bc74-4c2d-b35d-0401acd50367 .stackedline-graph .axis.x .guides:hover .guide.line,#chart-e4140fab-bc74-4c2d-b35d-0401acd50367 .xy-graph .axis.x .guides:hover .guide.line{stroke:rgba(0,0,0,1)}#chart-e4140fab-bc74-4c2d-b35d-0401acd50367 .axis .guides:hover text{fill:rgba(0,0,0,1)}#chart-e4140fab-bc74-4c2d-b35d-0401acd50367 .reactive{fill-opacity:.7;stroke-opacity:.8}#chart-e4140fab-bc74-4c2d-b35d-0401acd50367 .ci{stroke:rgba(0,0,0,.87)}#chart-e4140fab-bc74-4c2d-b35d-0401acd50367 .reactive.active,#chart-e4140fab-bc74-4c2d-b35d-0401acd50367 .active .reactive{fill-opacity:.8;stroke-opacity:.9;stroke-width:4}#chart-e4140fab-bc74-4c2d-b35d-0401acd50367 .ci .reactive.active{stroke-width:1.5}#chart-e4140fab-bc74-4c2d-b35d-0401acd50367 .series text{fill:rgba(0,0,0,1)}#chart-e4140fab-bc74-4c2d-b35d-0401acd50367 .tooltip rect{fill:rgba(255,255,255,1);stroke:rgba(0,0,0,1);-webkit-transition:opacity 150ms;-moz-transition:opacity 150ms;transition:opacity 150ms}#chart-e4140fab-bc74-4c2d-b35d-0401acd50367 .tooltip .label{fill:rgba(0,0,0,.87)}#chart-e4140fab-bc74-4c2d-b35d-0401acd50367 .tooltip .label{fill:rgba(0,0,0,.87)}#chart-e4140fab-bc74-4c2d-b35d-0401acd50367 .tooltip .legend{font-size:.8em;fill:rgba(0,0,0,.54)}#chart-e4140fab-bc74-4c2d-b35d-0401acd50367 .tooltip .x_label{font-size:.6em;fill:rgba(0,0,0,1)}#chart-e4140fab-bc74-4c2d-b35d-0401acd50367 .tooltip .xlink{font-size:.5em;text-decoration:underline}#chart-e4140fab-bc74-4c2d-b35d-0401acd50367 .tooltip .value{font-size:1.5em}#chart-e4140fab-bc74-4c2d-b35d-0401acd50367 .bound{font-size:.5em}#chart-e4140fab-bc74-4c2d-b35d-0401acd50367 .max-value{font-size:.75em;fill:rgba(0,0,0,.54)}#chart-e4140fab-bc74-4c2d-b35d-0401acd50367 .map-element{fill:rgba(255,255,255,1);stroke:rgba(0,0,0,.54) !important}#chart-e4140fab-bc74-4c2d-b35d-0401acd50367 .map-element .reactive{fill-opacity:inherit;stroke-opacity:inherit}#chart-e4140fab-bc74-4c2d-b35d-0401acd50367 .color-0,#chart-e4140fab-bc74-4c2d-b35d-0401acd50367 .color-0 a:visited{stroke:#f44336;fill:#f44336}#chart-e4140fab-bc74-4c2d-b35d-0401acd50367 .color-1,#chart-e4140fab-bc74-4c2d-b35d-0401acd50367 .color-1 a:visited{stroke:#3f51b5;fill:#3f51b5}#chart-e4140fab-bc74-4c2d-b35d-0401acd50367 .color-2,#chart-e4140fab-bc74-4c2d-b35d-0401acd50367 .color-2 a:visited{stroke:#009688;fill:#009688}#chart-e4140fab-bc74-4c2d-b35d-0401acd50367 .color-3,#chart-e4140fab-bc74-4c2d-b35d-0401acd50367 .color-3 a:visited{stroke:#ffc107;fill:#ffc107}#chart-e4140fab-bc74-4c2d-b35d-0401acd50367 .color-4,#chart-e4140fab-bc74-4c2d-b35d-0401acd50367 .color-4 a:visit ...

# %% [markdown]
# ##### We will now show a map with movie production countries and counts on it.
# ### 5. Use of World Map

# %% [markdown]
# For setup, we will run the pip command below to install from the file itself.

# %%
# !pip install pygal.maps.world
# Out:
# Processing /Users/mukulpathak/Library/Caches/pip/wheels/54/e6/11/5be0d3206bdc0ea8f0fcf1fe32661d7e614863c8b6a22655ae/pygal_maps_world-1.0.2-py3-none-any.whl
# Requirement already satisfied: pygal>=1.9.9 in /Users/mukulpathak/opt/miniconda3/lib/python3.7/site-packages (from pygal.maps.world) (2.4.0)
# Installing collected packages: pygal.maps.world
# Successfully installed pygal.maps.world

# %%
releaseCou=tmdb['production_countries'].value_counts() #get counts for each location

# %%
releaseCou
# Out:
# us    44
# ca     7
# gb     6
# cn     3
# in     2
# hk     1
# fl     1
# dk     1
# fr     1
# bg     1
# de     1
# mt     1
# jp     1
# au     1
# Name: production_countries, dtype: int64

# %% [markdown]
# NOTE : PyGal will plot locations when countries are stored in the country code format. You can learn about the country codes for each country from the official website : http://www.pygal.org/en/stable/documentation/types/maps/pygal_maps_world.html

# %%
#Convert Series into dictionary, PyGal works with dictionaries when it comes to maps. 
dictLoc = releaseCou.to_dict() 
dictLoc
# Out:
# {'us': 44,
#  'ca': 7,
#  'gb': 6,
#  'cn': 3,
#  'in': 2,
#  'hk': 1,
#  'fl': 1,
#  'dk': 1,
#  'fr': 1,
#  'bg': 1,
#  'de': 1,
#  'mt': 1,
#  'jp': 1,
#  'au': 1}

# %%
from pygal_maps_world.maps import World #import the world maps file from World package for PyGal

wm1= World() #store World() parameter in wm1

# %%
wm1.force_uri_protocol = 'http'
wm1.title="Map of primary movie production location"
wm1.add('In 2017', dictLoc)  #pass the series to the map

wm1.render_to_file('map.svg') #Since, the map won't be visible on the IPYNB file,store it locally on an SVG file.
